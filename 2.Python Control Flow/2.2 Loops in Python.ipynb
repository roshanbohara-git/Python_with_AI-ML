# %% [markdown]
# # Loops
# In Python, loops are control flow statements used to repeat a block of code multiple times, enabling efficient execution of task over sequences or based on conditions. There are two primary types of loops:
#
# i. for loop
#
# ii. while loop

# %% [markdown]
# ### For Loop
# for loop is used used to iterate over sequence of number

# %%
# 
range(5)
# Out:
# range(0, 5)

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,10,2):  # (start, stop, step)
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(10,1,-2):
    print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
## string
str = "Roshan Bohara"
for i in str:
    print(i)
# Out:
# R
# o
# s
# h
# a
# n
#
# B
# o
# h
# a
# r
# a

# %% [markdown]
# ### while loop
# The while loop continues to execute as long as the condition is True.

# %%
### while loop
count = 0
while count < 5:
    print(count)
    count = count+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
count = 0
while count%2 == 0:
    print(count)
    count = count + 1
# Out:
# 0

# %% [markdown]
# ### loop control statement
# - break
# - continue
# - pass

# %%
## Break
# The break statement exits the loop permanently

for i in range(10):
    if i == 5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
## Continue
# The continue statement skips the surrent iteration and continues with the next

for i in range(10):
    if i%2==0: # skips
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
## pass
# THe pass statement is a null operation: it does nothing.

for i in range(5):
    if i == 3:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# 17:47
