# %% [markdown]
# # Variables
# Variables are fundamental elements in programming used to store data that can be referenced and manipulated in a program. In Python, variables are created when you assign a value to them and they do not need explicit declaration to reserve memory space. The declaration happens automatically when you assign a value to a varibale.

# %% [markdown]
# **Variable** is a name given to memory location. A variable name can be pointer to the stored value(object). A variable can contain int, float, string, list, tuple, set, bool, predefined_variable etc. Variables are of two types: Local variable and Global Variable.

# %%
a = 100
name = 'Roshan Bohara'

# %% [markdown]
# ### Naming Conventions
# 1. Variables names should be descriptive and in small letter.
# 2. They must start with a letter or an '_" and contain letter, numbers and underscores
# 3. A variable can start from letter and underscore but it cannot start with a number.
# 4. Variables names are case sensitive
# 5. A variable can only contain alpha-numberic characters(a-Z, 0-9) and underscore(_).

# %%
# Declaring and asigning variables

age = 22
height = 5.8
name = "Roshan"
is_student = True

# printing the variables
print("Age :", age)
print("Height:", height)
print("Name:", name)
# Out:
# Age : 22
# Height: 5.8
# Name: Roshan

# %%
# Invalid variable names
# This is how you should not start your variable name
1age = 30
first-name = "Roshan"
@name = "Roshan"
# Out:
#   File "C:\Users\hp\AppData\Local\Temp\ipykernel_6444\3737299033.py", line 3
#     1age = 30
#     ^
# SyntaxError: invalid decimal literal

# %%
# Naming Conventions
first_name = "Roshan"
last_name = "Bohara"

# %% [markdown]
# ### Understanding Variable Types
# 1. Python is a dynamically typed which means type of a variable is determined at runtime.
# 2. Type Conversion
# 3. Dynamic Typing

# %%
age = 25 #int
height = 6.1 #float
name = "Roshan" #String
is_student = True #bool
print(type(name)) # this print the type of the variable
# Out:
# <class 'str'>

# %%
#2. Type Conversion
age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# 25
# <class 'str'>

# %%
age = "25"
print(type(int(age)))
# Out:
# <class 'int'>

# %%
#3. Dynamic Typing
## Python allows the type of a variable to change as the program execute
var = 10 #int
print(var,type(var))

var = "Hello"
print(var,type(var))

var = 3.14
print(var, type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
# input 
age = int(input("What is your age:"))
print(age,type(age))
# Out:
# 30 <class 'int'>

# %%
# Simple Calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1/ num2
print("sum:", sum)
print("Difference: ",difference)
print("Product: ", product)
print("Quotient: ", quotient)
# Out:
# sum: 23.0
# Difference:  -2.0
# Product:  131.25
# Quotient:  0.84
